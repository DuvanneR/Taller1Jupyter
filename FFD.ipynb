# %%
import cv2 #OpenCV
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
imagen = cv2.imread('D.JPG')

# %%
imagen
# Out:
# array([[[ 44,  58,  76],
#         [ 45,  59,  77],
#         [ 48,  62,  80],
#         ...,
#         [  6,   8,  18],
#         [  7,   9,  19],
#         [ 11,  13,  23]],
#
#        [[ 40,  56,  73],
#         [ 38,  54,  71],
#         [ 43,  57,  75],
#         ...,
#         [  6,   8,  18],
#         [  6,   8,  18],
#         [  9,  11,  21]],
#
#        [[ 32,  48,  65],
#         [ 33,  49,  66],
#         [ 39,  55,  72],
#         ...,
#         [  8,  10,  20],
#         [  8,  10,  20],
#         [ 11,  13,  23]],
#
#        ...,
#
#        [[154, 150, 145],
#         [153, 149, 144],
#         [152, 148, 143],
#         ...,
#         [179, 170, 157],
#         [178, 169, 156],
#         [178, 169, 156]],
#
#        [[153, 149, 144],
#         [153, 149, 144],
#         [151, 147, 142],
#         ...,
#         [181, 171, 161],
#         [179, 170, 157],
#         [181, 172, 159]],
#
#        [[153, 149, 144],
#         [154, 150, 145],
#         [152, 148, 143],
#         ...,
#         [180, 170, 160],
#         [176, 166, 156],
#         [180, 170, 160]]], dtype=uint8)

# %%
type(imagen)
# Out:
# numpy.ndarray

# %%
plt.imshow(imagen)

# %%
imagen2 = cv2.resize(imagen, (500, 500))

# %%
plt.imshow(imagen2)

# %%
imagen3 = cv2.flip(imagen, 1)

# %%
plt.imshow(imagen3)

# %%
imagen4 = cv2.flip(imagen, 0)

# %%
plt.imshow(imagen4)

# %%
imagen5 = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen5)

# %%
cv2.imwrite('D.JPG', imagen)
# Out:
# True

# %%
cv2.imwrite('D.JPG', imagen4)
# Out:
# True
